# %%
import pandas as pd
import json
import os
import matplotlib.pyplot as plt
import seaborn as sb
import matplotlib



from steves_utils.summary_utils import (
    get_experiments_from_path
)

from steves_utils.utils_v2 import (
    get_experiments_base_path
)

# %%
experiments_to_get = [
#     "oracle.run1.framed-cores_wisig",
    "cores_wisig-oracle.run1.framed",
]

experiments = {}

for experiment in experiments_to_get:
    print(experiment)
    experiments[experiment] = get_experiments_from_path(
        os.path.join(get_experiments_base_path(), "tl_3/A_killme", experiment)
    )
# Out:
# cores_wisig-oracle.run1.framed

# %%
all_trials = pd.DataFrame(columns=[
    "experiment_name",
    "source_val_label_accuracy",
    "target_val_label_accuracy",
    "x_transform",
])

# x_transform_mapping = {
#     tuple(["unit_power"]):"Unit Power",
#     tuple(["unit_mag"]): "Unit Magnitude",
#     tuple([]): "None"
# }

for experiment in experiments_to_get:   
    for trial in experiments[experiment]:
       
        datasets = trial["parameters"]["datasets"]

        x_transforms = set()
        for ds in datasets:
            trans = str(ds["x_transforms"])
            if "unit_mag" in trans: x_transforms.add("unit_mag")
            if "unit_power" in trans: x_transforms.add("unit_power")
                
            if "unit_mag" not in trans and "unit_power" not in trans:
                x_transforms.add("none")
        assert len(x_transforms) == 1
            
#         transforms = list(set( ( tuple() for d in datasets) ))

#         assert len(transforms) == 1
        
        f = pd.DataFrame(trial["results"])
        f["experiment_name"] = experiment
        f["x_transform"] =  x_transforms.pop()
#         f["x_transform"] = "A"
        f = f[all_trials.columns]
        
        f = f.iloc[0] # Unknown why, but pandas is repeating trials for each domain in the trial!
        
        
        all_trials = all_trials.append(f)
    
all_trials = all_trials.reset_index(drop=True)
all_trials
# Out:
#                    experiment_name  source_val_label_accuracy  \
# 0   cores_wisig-oracle.run1.framed                   0.941032
# 1   cores_wisig-oracle.run1.framed                   0.945447
# 2   cores_wisig-oracle.run1.framed                   0.957796
# 3   cores_wisig-oracle.run1.framed                   0.977419
# 4   cores_wisig-oracle.run1.framed                   0.957386
# 5   cores_wisig-oracle.run1.framed                   0.978147
# 6   cores_wisig-oracle.run1.framed                   0.968964
# 7   cores_wisig-oracle.run1.framed                   0.972793
# 8   cores_wisig-oracle.run1.framed                   0.979811
# 9   cores_wisig-oracle.run1.framed                   0.968857
# 10  cores_wisig-oracle.run1.framed                   0.972938
# 11  cores_wisig-oracle.run1.framed                   0.949635
# 12  cores_wisig-oracle.run1.framed                   0.963668
# 13  cores_wisig-oracle.run1.framed                   0.942474
# 14  cores_wisig-oracle.run1.framed                   0.969399
#
#     target_val_label_accuracy x_transform
# 0                    0.218262  unit_power
# 1                    0.233268    unit_mag
# 2                    0.191374  unit_power
# 3                    0.493262        none
# 4                    0.186979  unit_power
# 5                    0.286458        none
# 6                    0.181087    unit_mag
# 7                    0.212467    unit_mag
# 8                    0.364160        none
# 9                    0.208887    unit_mag
# 10                   0.467350        none
# 11                   0.241211  unit_power
# 12                   0.189551    unit_mag
# 13                   0.168359  unit_power
# 14                   0.535189        none

# %%
m = pd.melt(all_trials, 
        id_vars=["experiment_name", "x_transform"], 
        value_vars=[
            "source_val_label_accuracy",
            "target_val_label_accuracy",
        ])
m
# Out:
#                    experiment_name x_transform                   variable  \
# 0   cores_wisig-oracle.run1.framed  unit_power  source_val_label_accuracy
# 1   cores_wisig-oracle.run1.framed    unit_mag  source_val_label_accuracy
# 2   cores_wisig-oracle.run1.framed  unit_power  source_val_label_accuracy
# 3   cores_wisig-oracle.run1.framed        none  source_val_label_accuracy
# 4   cores_wisig-oracle.run1.framed  unit_power  source_val_label_accuracy
# 5   cores_wisig-oracle.run1.framed        none  source_val_label_accuracy
# 6   cores_wisig-oracle.run1.framed    unit_mag  source_val_label_accuracy
# 7   cores_wisig-oracle.run1.framed    unit_mag  source_val_label_accuracy
# 8   cores_wisig-oracle.run1.framed        none  source_val_label_accuracy
# 9   cores_wisig-oracle.run1.framed    unit_mag  source_val_label_accuracy
# 10  cores_wisig-oracle.run1.framed        none  source_val_label_accuracy
# 11  cores_wisig-oracle.run1.framed  unit_power  source_val_label_accuracy
# 12  cores_wisig-oracle.run1.framed    unit_mag  source_val_label_accuracy
# 13  cores_wisig-oracle.run1.framed  unit_power  source_val_label_accuracy
# 14  cores_wisig-oracle.run1.framed        none  source_val_label_accuracy
# 15  cores_wisig-oracle.run1.framed  unit_power  target_val_label_accuracy
# 16  cores_wisig-oracle.run1.framed    unit_mag  target_val_label_accuracy
# 17  cores_wisig-oracle.run1.framed  unit_power  target_val_label_accuracy
# 18  cores_wisig-oracle.run1.framed        none  target_val_label_accuracy
# 19  cores_wisig-oracle.run1.framed  unit_power  target_val_label_accuracy
# 20  cores_wisig-oracle.run1.framed        none  target_val_label_accuracy
# 21  cores_wisig-oracle.run1.framed    unit_mag  target_val_label_accuracy
# 22  cores_wisig-oracle.run1.framed    unit_mag  target_val_label_accuracy
# 23  cores_wisig-oracle.run1.framed        none  target_val_label_accuracy
# 24  cores_wisig-oracle.run1.framed    unit_mag  target_val_label_accuracy
# 25  cores_wisig-oracle.run1.framed        none  target_val_label_accuracy
# 26  cores_wisig-oracle.run1.framed  unit_power  target_val_label_accuracy
# 27  cores_wisig-oracle.run1.framed    unit_mag  target_val_label_accuracy
# 28  cores_wisig-oracle.run1.framed  unit_power  target_val_label_accuracy
# 29  cores_wisig-oracle.run1.framed        none  target_val_label_accuracy
#
#        value
# 0   0.941032
# 1   0.945447
# 2   0.957796
# 3   0.977419
# 4   0.957386
# 5   0.978147
# 6   0.968964
# 7   0.972793
# 8   0.979811
# 9   0.968857
# 10  0.972938
# 11  0.949635
# 12  0.963668
# 13  0.942474
# 14  0.969399
# 15  0.218262
# 16  0.233268
# 17  0.191374
# 18  0.493262
# 19  0.186979
# 20  0.286458
# 21  0.181087
# 22  0.212467
# 23  0.364160
# 24  0.208887
# 25  0.467350
# 26  0.241211
# 27  0.189551
# 28  0.168359
# 29  0.535189

# %%
matplotlib.rcParams.update({'font.size': 22})
plt.style.use('seaborn-whitegrid')

fg = sb.catplot(x='x_transform', col="experiment_name", y='value', hue='variable', 
                        data=m, kind='bar', height=5, aspect=3, col_wrap=2, edgecolor = "black")
fg.set_xlabels('')
plt.figure(figsize=(15,50))

# iterate through axes
for ax in fg.axes.ravel():
    
    ax.tick_params(labelbottom=True)
    
    # add annotations
    for c in ax.containers:
        labels = [f'{(v.get_height()):.2f}' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge')
    ax.margins(y=0.2)

# %%
# Pick the best trials based on target (on a per experiment+x_transform basis)
idx = all_trials.groupby(["experiment_name", "x_transform"])["target_val_label_accuracy"].transform(max) == all_trials["target_val_label_accuracy"]
all_trials = all_trials[idx]

m = pd.melt(all_trials, 
        id_vars=["experiment_name", "x_transform"], 
        value_vars=[
            "source_val_label_accuracy",
            "target_val_label_accuracy",
        ])

matplotlib.rcParams.update({'font.size': 22})
plt.style.use('seaborn-whitegrid')

fg = sb.catplot(x='x_transform', col="experiment_name", y='value', hue='variable', 
                        data=m, kind='bar', height=5, aspect=3, col_wrap=2, edgecolor = "black")
fg.set_xlabels('')
plt.figure(figsize=(15,50))

# iterate through axes
for ax in fg.axes.ravel():
    
    ax.tick_params(labelbottom=True)
    
    # add annotations
    for c in ax.containers:
        labels = [f'{(v.get_height()):.2f}' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge')
    ax.margins(y=0.2)
