# %%
import pandas as pd
import json
import os
import matplotlib.pyplot as plt
import seaborn as sb
import matplotlib



from steves_utils.summary_utils import (
    get_experiments_from_path
)

from steves_utils.utils_v2 import (
    get_experiments_base_path
)

# %%
experiments_to_get = [
    "oracle.run1.framed-cores_wisig",
    "cores_wisig-oracle.run1.framed",
]

experiments = {}

for experiment in experiments_to_get:
    print(experiment)
    experiments[experiment] = get_experiments_from_path(
        os.path.join(get_experiments_base_path(), "tl_3/A_killme", experiment)
    )
# Out:
# oracle.run1.framed-cores_wisig
# cores_wisig-oracle.run1.framed

# %%
all_trials = pd.DataFrame(columns=[
    "experiment_name",
    "source_val_label_accuracy",
    "target_val_label_accuracy",
    "x_transform",
])

# x_transform_mapping = {
#     tuple(["unit_power"]):"Unit Power",
#     tuple(["unit_mag"]): "Unit Magnitude",
#     tuple([]): "None"
# }

for experiment in experiments_to_get:   
    for trial in experiments[experiment]:
       
        datasets = trial["parameters"]["datasets"]

        x_transforms = set()
        for ds in datasets:
            trans = str(ds["x_transforms"])
            if "unit_mag" in trans: x_transforms.add("unit_mag")
            if "unit_power" in trans: x_transforms.add("unit_power")
                
            if "unit_mag" not in trans and "unit_power" not in trans:
                x_transforms.add("none")
        assert len(x_transforms) == 1
            
#         transforms = list(set( ( tuple() for d in datasets) ))

#         assert len(transforms) == 1
        
        f = pd.DataFrame(trial["results"])
        f["experiment_name"] = experiment
        f["x_transform"] =  x_transforms.pop()
#         f["x_transform"] = "A"
        f = f[all_trials.columns]
        
        f = f.iloc[0] # Unknown why, but pandas is repeating trials for each domain in the trial!
        
        
        all_trials = all_trials.append(f)
    
all_trials = all_trials.reset_index(drop=True)
all_trials
# Out:
#                    experiment_name  source_val_label_accuracy  \
# 0   oracle.run1.framed-cores_wisig                   0.704036
# 1   oracle.run1.framed-cores_wisig                   0.737142
# 2   oracle.run1.framed-cores_wisig                   0.811296
# 3   oracle.run1.framed-cores_wisig                   0.857747
# 4   oracle.run1.framed-cores_wisig                   0.746517
# 5   oracle.run1.framed-cores_wisig                   0.913900
# 6   oracle.run1.framed-cores_wisig                   0.691504
# 7   oracle.run1.framed-cores_wisig                   0.734635
# 8   oracle.run1.framed-cores_wisig                   0.878613
# 9   oracle.run1.framed-cores_wisig                   0.740169
# 10  oracle.run1.framed-cores_wisig                   0.881413
# 11  oracle.run1.framed-cores_wisig                   0.610840
# 12  oracle.run1.framed-cores_wisig                   0.817871
# 13  oracle.run1.framed-cores_wisig                   0.831055
# 14  oracle.run1.framed-cores_wisig                   0.873014
# 15  cores_wisig-oracle.run1.framed                   0.941032
# 16  cores_wisig-oracle.run1.framed                   0.945447
# 17  cores_wisig-oracle.run1.framed                   0.957796
# 18  cores_wisig-oracle.run1.framed                   0.977419
# 19  cores_wisig-oracle.run1.framed                   0.957386
# 20  cores_wisig-oracle.run1.framed                   0.978147
# 21  cores_wisig-oracle.run1.framed                   0.968964
# 22  cores_wisig-oracle.run1.framed                   0.972793
# 23  cores_wisig-oracle.run1.framed                   0.979811
# 24  cores_wisig-oracle.run1.framed                   0.968857
# 25  cores_wisig-oracle.run1.framed                   0.972938
# 26  cores_wisig-oracle.run1.framed                   0.949635
# 27  cores_wisig-oracle.run1.framed                   0.963668
# 28  cores_wisig-oracle.run1.framed                   0.942474
# 29  cores_wisig-oracle.run1.framed                   0.969399
#
#     target_val_label_accuracy x_transform
# 0                    0.575985  unit_power
# 1                    0.665915    unit_mag
# 2                    0.585803  unit_power
# 3                    0.610017        none
# 4                    0.542395  unit_power
# 5                    0.612434        none
# 6                    0.556614    unit_mag
# 7                    0.543051    unit_mag
# 8                    0.787908        none
# 9                    0.610395    unit_mag
# 10                   0.626074        none
# 11                   0.600945  unit_power
# 12                   0.625541    unit_mag
# 13                   0.625108  unit_power
# 14                   0.442798        none
# 15                   0.218262  unit_power
# 16                   0.233268    unit_mag
# 17                   0.191374  unit_power
# 18                   0.493262        none
# 19                   0.186979  unit_power
# 20                   0.286458        none
# 21                   0.181087    unit_mag
# 22                   0.212467    unit_mag
# 23                   0.364160        none
# 24                   0.208887    unit_mag
# 25                   0.467350        none
# 26                   0.241211  unit_power
# 27                   0.189551    unit_mag
# 28                   0.168359  unit_power
# 29                   0.535189        none

# %%
m = pd.melt(all_trials, 
        id_vars=["experiment_name", "x_transform"], 
        value_vars=[
            "source_val_label_accuracy",
            "target_val_label_accuracy",
        ])
m
# Out:
#                    experiment_name x_transform                   variable  \
# 0   oracle.run1.framed-cores_wisig  unit_power  source_val_label_accuracy
# 1   oracle.run1.framed-cores_wisig    unit_mag  source_val_label_accuracy
# 2   oracle.run1.framed-cores_wisig  unit_power  source_val_label_accuracy
# 3   oracle.run1.framed-cores_wisig        none  source_val_label_accuracy
# 4   oracle.run1.framed-cores_wisig  unit_power  source_val_label_accuracy
# 5   oracle.run1.framed-cores_wisig        none  source_val_label_accuracy
# 6   oracle.run1.framed-cores_wisig    unit_mag  source_val_label_accuracy
# 7   oracle.run1.framed-cores_wisig    unit_mag  source_val_label_accuracy
# 8   oracle.run1.framed-cores_wisig        none  source_val_label_accuracy
# 9   oracle.run1.framed-cores_wisig    unit_mag  source_val_label_accuracy
# 10  oracle.run1.framed-cores_wisig        none  source_val_label_accuracy
# 11  oracle.run1.framed-cores_wisig  unit_power  source_val_label_accuracy
# 12  oracle.run1.framed-cores_wisig    unit_mag  source_val_label_accuracy
# 13  oracle.run1.framed-cores_wisig  unit_power  source_val_label_accuracy
# 14  oracle.run1.framed-cores_wisig        none  source_val_label_accuracy
# 15  cores_wisig-oracle.run1.framed  unit_power  source_val_label_accuracy
# 16  cores_wisig-oracle.run1.framed    unit_mag  source_val_label_accuracy
# 17  cores_wisig-oracle.run1.framed  unit_power  source_val_label_accuracy
# 18  cores_wisig-oracle.run1.framed        none  source_val_label_accuracy
# 19  cores_wisig-oracle.run1.framed  unit_power  source_val_label_accuracy
# 20  cores_wisig-oracle.run1.framed        none  source_val_label_accuracy
# 21  cores_wisig-oracle.run1.framed    unit_mag  source_val_label_accuracy
# 22  cores_wisig-oracle.run1.framed    unit_mag  source_val_label_accuracy
# 23  cores_wisig-oracle.run1.framed        none  source_val_label_accuracy
# 24  cores_wisig-oracle.run1.framed    unit_mag  source_val_label_accuracy
# 25  cores_wisig-oracle.run1.framed        none  source_val_label_accuracy
# 26  cores_wisig-oracle.run1.framed  unit_power  source_val_label_accuracy
# 27  cores_wisig-oracle.run1.framed    unit_mag  source_val_label_accuracy
# 28  cores_wisig-oracle.run1.framed  unit_power  source_val_label_accuracy
# 29  cores_wisig-oracle.run1.framed        none  source_val_label_accuracy
# 30  oracle.run1.framed-cores_wisig  unit_power  target_val_label_accuracy
# 31  oracle.run1.framed-cores_wisig    unit_mag  target_val_label_accuracy
# 32  oracle.run1.framed-cores_wisig  unit_power  target_val_label_accuracy
# 33  oracle.run1.framed-cores_wisig        none  target_val_label_accuracy
# 34  oracle.run1.framed-cores_wisig  unit_power  target_val_label_accuracy
# 35  oracle.run1.framed-cores_wisig        none  target_val_label_accuracy
# 36  oracle.run1.framed-cores_wisig    unit_mag  target_val_label_accuracy
# 37  oracle.run1.framed-cores_wisig    unit_mag  target_val_label_accuracy
# 38  oracle.run1.framed-cores_wisig        none  target_val_label_accuracy
# 39  oracle.run1.framed-cores_wisig    unit_mag  target_val_label_accuracy
# 40  oracle.run1.framed-cores_wisig        none  target_val_label_accuracy
# 41  oracle.run1.framed-cores_wisig  unit_power  target_val_label_accuracy
# 42  oracle.run1.framed-cores_wisig    unit_mag  target_val_label_accuracy
# 43  oracle.run1.framed-cores_wisig  unit_power  target_val_label_accuracy
# 44  oracle.run1.framed-cores_wisig        none  target_val_label_accuracy
# 45  cores_wisig-oracle.run1.framed  unit_power  target_val_label_accuracy
# 46  cores_wisig-oracle.run1.framed    unit_mag  target_val_label_accuracy
# 47  cores_wisig-oracle.run1.framed  unit_power  target_val_label_accuracy
# 48  cores_wisig-oracle.run1.framed        none  target_val_label_accuracy
# 49  cores_wisig-oracle.run1.framed  unit_power  target_val_label_accuracy
# 50  cores_wisig-oracle.run1.framed        none  target_val_label_accuracy
# 51  cores_wisig-oracle.run1.framed    unit_mag  target_val_label_accuracy
# 52  cores_wisig-oracle.run1.framed    unit_mag  target_val_label_accuracy
# 53  cores_wisig-oracle.run1.framed        none  target_val_label_accuracy
# 54  cores_wisig-oracle.run1.framed    unit_mag  target_val_label_accuracy
# 55  cores_wisig-oracle.run1.framed        none  target_val_label_accuracy
# 56  cores_wisig-oracle.run1.framed  unit_power  target_val_label_accuracy
# 57  cores_wisig-oracle.run1.framed    unit_mag  target_val_label_accuracy
# 58  cores_wisig-oracle.run1.framed  unit_power  target_val_label_accuracy
# 59  cores_wisig-oracle.run1.framed        none  target_val_label_accuracy
#
#        value
# 0   0.704036
# 1   0.737142
# 2   0.811296
# 3   0.857747
# 4   0.746517
# 5   0.913900
# 6   0.691504
# 7   0.734635
# 8   0.878613
# 9   0.740169
# 10  0.881413
# 11  0.610840
# 12  0.817871
# 13  0.831055
# 14  0.873014
# 15  0.941032
# 16  0.945447
# 17  0.957796
# 18  0.977419
# 19  0.957386
# 20  0.978147
# 21  0.968964
# 22  0.972793
# 23  0.979811
# 24  0.968857
# 25  0.972938
# 26  0.949635
# 27  0.963668
# 28  0.942474
# 29  0.969399
# 30  0.575985
# 31  0.665915
# 32  0.585803
# 33  0.610017
# 34  0.542395
# 35  0.612434
# 36  0.556614
# 37  0.543051
# 38  0.787908
# 39  0.610395
# 40  0.626074
# 41  0.600945
# 42  0.625541
# 43  0.625108
# 44  0.442798
# 45  0.218262
# 46  0.233268
# 47  0.191374
# 48  0.493262
# 49  0.186979
# 50  0.286458
# 51  0.181087
# 52  0.212467
# 53  0.364160
# 54  0.208887
# 55  0.467350
# 56  0.241211
# 57  0.189551
# 58  0.168359
# 59  0.535189

# %%
matplotlib.rcParams.update({'font.size': 22})
plt.style.use('seaborn-whitegrid')

fg = sb.catplot(x='x_transform', col="experiment_name", y='value', hue='variable', 
                        data=m, kind='bar', height=5, aspect=3, col_wrap=2, edgecolor = "black")
fg.set_xlabels('')
plt.figure(figsize=(15,50))

# iterate through axes
for ax in fg.axes.ravel():
    
    ax.tick_params(labelbottom=True)
    
    # add annotations
    for c in ax.containers:
        labels = [f'{(v.get_height()):.2f}' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge')
    ax.margins(y=0.2)

# %%
# Pick the best trials based on target (on a per experiment+x_transform basis)
idx = all_trials.groupby(["experiment_name", "x_transform"])["target_val_label_accuracy"].transform(max) == all_trials["target_val_label_accuracy"]
all_trials = all_trials[idx]

m = pd.melt(all_trials, 
        id_vars=["experiment_name", "x_transform"], 
        value_vars=[
            "source_val_label_accuracy",
            "target_val_label_accuracy",
        ])

matplotlib.rcParams.update({'font.size': 22})
plt.style.use('seaborn-whitegrid')

fg = sb.catplot(x='x_transform', col="experiment_name", y='value', hue='variable', 
                        data=m, kind='bar', height=5, aspect=3, col_wrap=2, edgecolor = "black")
fg.set_xlabels('')
plt.figure(figsize=(15,50))

# iterate through axes
for ax in fg.axes.ravel():
    
    ax.tick_params(labelbottom=True)
    
    # add annotations
    for c in ax.containers:
        labels = [f'{(v.get_height()):.2f}' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge')
    ax.margins(y=0.2)
