# %%
import pandas as pd
import json
import os
import matplotlib.pyplot as plt
import seaborn as sb
import matplotlib



from steves_utils.summary_utils import (
    get_experiments_from_path
)

from steves_utils.utils_v2 import (
    get_experiments_base_path
)

# %%
experiments_to_get = [
    "cores-oracle.run1.framed",
    "oracle.run1.framed-oracle.run2.framed",
#     "cores-metehan",
    "wisig-oracle.run1.framed",
    "oracle.run1-oracle.run2",
    "wisig-oracle.run1",
    "cores-wisig",
#     "wisig-metehan",
    "cores-oracle.run1",
]

experiments = {}

for experiment in experiments_to_get:
    print(experiment)
    experiments[experiment] = get_experiments_from_path(
        os.path.join(get_experiments_base_path(), "tl_1", experiment)
    )
# Out:
# cores-oracle.run1.framed
# oracle.run1.framed-oracle.run2.framed
# wisig-oracle.run1.framed
# oracle.run1-oracle.run2
# wisig-oracle.run1
# cores-wisig
# cores-oracle.run1

# %%
all_trials = pd.DataFrame(columns=[
    "experiment_name",
    "source_val_label_accuracy",
    "target_val_label_accuracy",
    "x_transform",
    "source_ds",
    "target_ds",
])

pickle_name_mapping = {
    "cores.stratified_ds.2022A.pkl": "cores",
    "metehan.stratified_ds.2022A.pkl": "metehan",
    "oracle.Run1_10kExamples_stratified_ds.2022A.pkl": "oracle.run1",
    "oracle.Run1_framed_2000Examples_stratified_ds.2022A.pkl": "oracle.run1.framed",
    "oracle.Run2_10kExamples_stratified_ds.2022A.pkl": "oracle.run2",
    "oracle.Run2_framed_2000Examples_stratified_ds.2022A.pkl": "oracle.run2.framed",
    "wisig.node3-19.stratified_ds.2022A.pkl": "wisig",
}

x_transform_mapping = {
    tuple(["unit_power"]):"Unit Power",
    tuple(["unit_mag"]): "Unit Magnitude",
    tuple([]): "None"
}

counter = 6

for experiment in experiments_to_get:   
    for trial in experiments[experiment]:
       
        datasets = trial["parameters"]["datasets"]
        assert len(datasets) == 2

        if datasets[0]["source_or_target_dataset"] == "source":
            source = datasets[0]
            target = datasets[1]
        else:
            target = datasets[0]
            source = datasets[1]
        
        source_name = os.path.basename(source["pickle_path"])
        target_name = os.path.basename(target["pickle_path"])
        
        source_name = pickle_name_mapping[source_name]
        target_name = pickle_name_mapping[target_name]
        
        
        assert source["x_transforms"] == target["x_transforms"]
        
        f = pd.DataFrame(trial["results"])
        f["experiment_name"] = experiment
        f["x_transform"] =  x_transform_mapping[tuple(source["x_transforms"])]
        f["source_ds"] = source_name
        f["target_ds"] = target_name
        f = f[all_trials.columns]
        
        f = f.iloc[0] # Unknown why, but pandas is repeating trials for each domain in the trial!
        
        
        all_trials = all_trials.append(f)
    
all_trials = all_trials.reset_index(drop=True)
all_trials
# Out:
#                           experiment_name  source_val_label_accuracy  \
# 0                cores-oracle.run1.framed                   0.989375
# 1                cores-oracle.run1.framed                   0.869954
# 2                cores-oracle.run1.framed                   0.996250
# 3                cores-oracle.run1.framed                   0.987812
# 4                cores-oracle.run1.framed                   0.801465
# 5                cores-oracle.run1.framed                   0.917546
# 6   oracle.run1.framed-oracle.run2.framed                   0.896615
# 7   oracle.run1.framed-oracle.run2.framed                   0.892839
# 8   oracle.run1.framed-oracle.run2.framed                   0.946224
# 9   oracle.run1.framed-oracle.run2.framed                   0.897135
# 10  oracle.run1.framed-oracle.run2.framed                   0.897982
# 11  oracle.run1.framed-oracle.run2.framed                   0.941895
# 12               wisig-oracle.run1.framed                   0.958171
# 13               wisig-oracle.run1.framed                   0.786003
# 14               wisig-oracle.run1.framed                   0.970378
# 15               wisig-oracle.run1.framed                   0.935059
# 16               wisig-oracle.run1.framed                   0.801465
# 17               wisig-oracle.run1.framed                   0.917546
# 18                oracle.run1-oracle.run2                   0.743828
# 19                oracle.run1-oracle.run2                   0.735365
# 20                oracle.run1-oracle.run2                   0.878496
# 21                oracle.run1-oracle.run2                   0.739980
# 22                oracle.run1-oracle.run2                   0.738346
# 23                oracle.run1-oracle.run2                   0.877409
# 24                      wisig-oracle.run1                   0.958171
# 25                      wisig-oracle.run1                   0.696569
# 26                      wisig-oracle.run1                   0.966960
# 27                      wisig-oracle.run1                   0.935059
# 28                      wisig-oracle.run1                   0.704661
# 29                      wisig-oracle.run1                   0.667637
# 30                            cores-wisig                   0.991667
# 31                            cores-wisig                   0.954023
# 32                            cores-wisig                   0.988793
# 33                            cores-wisig                   0.992816
# 34                            cores-wisig                   0.937500
# 35                            cores-wisig                   0.954741
# 36                      cores-oracle.run1                   0.989375
# 37                      cores-oracle.run1                   0.743828
# 38                      cores-oracle.run1                   0.995625
# 39                      cores-oracle.run1                   0.993125
# 40                      cores-oracle.run1                   0.704661
# 41                      cores-oracle.run1                   0.667637
#
#     target_val_label_accuracy     x_transform           source_ds  \
# 0                    0.215820      Unit Power               cores
# 1                    0.866563      Unit Power  oracle.run1.framed
# 2                    0.527474            None               cores
# 3                    0.320312  Unit Magnitude               cores
# 4                    0.801562  Unit Magnitude  oracle.run1.framed
# 5                    0.839688            None  oracle.run1.framed
# 6                    0.872266      Unit Power  oracle.run1.framed
# 7                    0.879753      Unit Power  oracle.run2.framed
# 8                    0.936979            None  oracle.run1.framed
# 9                    0.873665  Unit Magnitude  oracle.run1.framed
# 10                   0.882520  Unit Magnitude  oracle.run2.framed
# 11                   0.928060            None  oracle.run2.framed
# 12                   0.177311      Unit Power               wisig
# 13                   0.587565      Unit Power  oracle.run1.framed
# 14                   0.281120            None               wisig
# 15                   0.163997  Unit Magnitude               wisig
# 16                   0.604980  Unit Magnitude  oracle.run1.framed
# 17                   0.725586            None  oracle.run1.framed
# 18                   0.729043      Unit Power         oracle.run1
# 19                   0.738906      Unit Power         oracle.run2
# 20                   0.869316            None         oracle.run1
# 21                   0.720775  Unit Magnitude         oracle.run1
# 22                   0.740026  Unit Magnitude         oracle.run2
# 23                   0.852493            None         oracle.run2
# 24                   0.103743      Unit Power               wisig
# 25                   0.237956      Unit Power         oracle.run1
# 26                   0.229128            None               wisig
# 27                   0.107669  Unit Magnitude               wisig
# 28                   0.746419  Unit Magnitude         oracle.run1
# 29                   0.560221            None         oracle.run1
# 30                   0.690374      Unit Power               cores
# 31                   0.951149      Unit Power               wisig
# 32                   0.723060            None               cores
# 33                   0.700790  Unit Magnitude               cores
# 34                   0.963793  Unit Magnitude               wisig
# 35                   0.970977            None               wisig
# 36                   0.122526      Unit Power               cores
# 37                   0.971250      Unit Power         oracle.run1
# 38                   0.388379            None               cores
# 39                   0.119036  Unit Magnitude               cores
# 40                   0.966562  Unit Magnitude         oracle.run1
# 41                   0.761563            None         oracle.run1
#
#              target_ds
# 0   oracle.run1.framed
# 1                cores
# 2   oracle.run1.framed
# 3   oracle.run1.framed
# 4                cores
# 5                cores
# 6   oracle.run2.framed
# 7   oracle.run1.framed
# 8   oracle.run2.framed
# 9   oracle.run2.framed
# 10  oracle.run1.framed
# 11  oracle.run1.framed
# 12  oracle.run1.framed
# 13               wisig
# 14  oracle.run1.framed
# 15  oracle.run1.framed
# 16               wisig
# 17               wisig
# 18         oracle.run2
# 19         oracle.run1
# 20         oracle.run2
# 21         oracle.run2
# 22         oracle.run1
# 23         oracle.run1
# 24         oracle.run1
# 25               wisig
# 26         oracle.run1
# 27         oracle.run1
# 28               wisig
# 29               wisig
# 30               wisig
# 31               cores
# 32               wisig
# 33               wisig
# 34               cores
# 35               cores
# 36         oracle.run1
# 37               cores
# 38         oracle.run1
# 39         oracle.run1
# 40               cores
# 41               cores

# %%
all_trials["Transfer"] = all_trials["source_ds"] + "->" + all_trials["target_ds"]
all_trials
# Out:
#                           experiment_name  source_val_label_accuracy  \
# 0                cores-oracle.run1.framed                   0.989375
# 1                cores-oracle.run1.framed                   0.869954
# 2                cores-oracle.run1.framed                   0.996250
# 3                cores-oracle.run1.framed                   0.987812
# 4                cores-oracle.run1.framed                   0.801465
# 5                cores-oracle.run1.framed                   0.917546
# 6   oracle.run1.framed-oracle.run2.framed                   0.896615
# 7   oracle.run1.framed-oracle.run2.framed                   0.892839
# 8   oracle.run1.framed-oracle.run2.framed                   0.946224
# 9   oracle.run1.framed-oracle.run2.framed                   0.897135
# 10  oracle.run1.framed-oracle.run2.framed                   0.897982
# 11  oracle.run1.framed-oracle.run2.framed                   0.941895
# 12               wisig-oracle.run1.framed                   0.958171
# 13               wisig-oracle.run1.framed                   0.786003
# 14               wisig-oracle.run1.framed                   0.970378
# 15               wisig-oracle.run1.framed                   0.935059
# 16               wisig-oracle.run1.framed                   0.801465
# 17               wisig-oracle.run1.framed                   0.917546
# 18                oracle.run1-oracle.run2                   0.743828
# 19                oracle.run1-oracle.run2                   0.735365
# 20                oracle.run1-oracle.run2                   0.878496
# 21                oracle.run1-oracle.run2                   0.739980
# 22                oracle.run1-oracle.run2                   0.738346
# 23                oracle.run1-oracle.run2                   0.877409
# 24                      wisig-oracle.run1                   0.958171
# 25                      wisig-oracle.run1                   0.696569
# 26                      wisig-oracle.run1                   0.966960
# 27                      wisig-oracle.run1                   0.935059
# 28                      wisig-oracle.run1                   0.704661
# 29                      wisig-oracle.run1                   0.667637
# 30                            cores-wisig                   0.991667
# 31                            cores-wisig                   0.954023
# 32                            cores-wisig                   0.988793
# 33                            cores-wisig                   0.992816
# 34                            cores-wisig                   0.937500
# 35                            cores-wisig                   0.954741
# 36                      cores-oracle.run1                   0.989375
# 37                      cores-oracle.run1                   0.743828
# 38                      cores-oracle.run1                   0.995625
# 39                      cores-oracle.run1                   0.993125
# 40                      cores-oracle.run1                   0.704661
# 41                      cores-oracle.run1                   0.667637
#
#     target_val_label_accuracy     x_transform           source_ds  \
# 0                    0.215820      Unit Power               cores
# 1                    0.866563      Unit Power  oracle.run1.framed
# 2                    0.527474            None               cores
# 3                    0.320312  Unit Magnitude               cores
# 4                    0.801562  Unit Magnitude  oracle.run1.framed
# 5                    0.839688            None  oracle.run1.framed
# 6                    0.872266      Unit Power  oracle.run1.framed
# 7                    0.879753      Unit Power  oracle.run2.framed
# 8                    0.936979            None  oracle.run1.framed
# 9                    0.873665  Unit Magnitude  oracle.run1.framed
# 10                   0.882520  Unit Magnitude  oracle.run2.framed
# 11                   0.928060            None  oracle.run2.framed
# 12                   0.177311      Unit Power               wisig
# 13                   0.587565      Unit Power  oracle.run1.framed
# 14                   0.281120            None               wisig
# 15                   0.163997  Unit Magnitude               wisig
# 16                   0.604980  Unit Magnitude  oracle.run1.framed
# 17                   0.725586            None  oracle.run1.framed
# 18                   0.729043      Unit Power         oracle.run1
# 19                   0.738906      Unit Power         oracle.run2
# 20                   0.869316            None         oracle.run1
# 21                   0.720775  Unit Magnitude         oracle.run1
# 22                   0.740026  Unit Magnitude         oracle.run2
# 23                   0.852493            None         oracle.run2
# 24                   0.103743      Unit Power               wisig
# 25                   0.237956      Unit Power         oracle.run1
# 26                   0.229128            None               wisig
# 27                   0.107669  Unit Magnitude               wisig
# 28                   0.746419  Unit Magnitude         oracle.run1
# 29                   0.560221            None         oracle.run1
# 30                   0.690374      Unit Power               cores
# 31                   0.951149      Unit Power               wisig
# 32                   0.723060            None               cores
# 33                   0.700790  Unit Magnitude               cores
# 34                   0.963793  Unit Magnitude               wisig
# 35                   0.970977            None               wisig
# 36                   0.122526      Unit Power               cores
# 37                   0.971250      Unit Power         oracle.run1
# 38                   0.388379            None               cores
# 39                   0.119036  Unit Magnitude               cores
# 40                   0.966562  Unit Magnitude         oracle.run1
# 41                   0.761563            None         oracle.run1
#
#              target_ds                                Transfer
# 0   oracle.run1.framed               cores->oracle.run1.framed
# 1                cores               oracle.run1.framed->cores
# 2   oracle.run1.framed               cores->oracle.run1.framed
# 3   oracle.run1.framed               cores->oracle.run1.framed
# 4                cores               oracle.run1.framed->cores
# 5                cores               oracle.run1.framed->cores
# 6   oracle.run2.framed  oracle.run1.framed->oracle.run2.framed
# 7   oracle.run1.framed  oracle.run2.framed->oracle.run1.framed
# 8   oracle.run2.framed  oracle.run1.framed->oracle.run2.framed
# 9   oracle.run2.framed  oracle.run1.framed->oracle.run2.framed
# 10  oracle.run1.framed  oracle.run2.framed->oracle.run1.framed
# 11  oracle.run1.framed  oracle.run2.framed->oracle.run1.framed
# 12  oracle.run1.framed               wisig->oracle.run1.framed
# 13               wisig               oracle.run1.framed->wisig
# 14  oracle.run1.framed               wisig->oracle.run1.framed
# 15  oracle.run1.framed               wisig->oracle.run1.framed
# 16               wisig               oracle.run1.framed->wisig
# 17               wisig               oracle.run1.framed->wisig
# 18         oracle.run2                oracle.run1->oracle.run2
# 19         oracle.run1                oracle.run2->oracle.run1
# 20         oracle.run2                oracle.run1->oracle.run2
# 21         oracle.run2                oracle.run1->oracle.run2
# 22         oracle.run1                oracle.run2->oracle.run1
# 23         oracle.run1                oracle.run2->oracle.run1
# 24         oracle.run1                      wisig->oracle.run1
# 25               wisig                      oracle.run1->wisig
# 26         oracle.run1                      wisig->oracle.run1
# 27         oracle.run1                      wisig->oracle.run1
# 28               wisig                      oracle.run1->wisig
# 29               wisig                      oracle.run1->wisig
# 30               wisig                            cores->wisig
# 31               cores                            wisig->cores
# 32               wisig                            cores->wisig
# 33               wisig                            cores->wisig
# 34               cores                            wisig->cores
# 35               cores                            wisig->cores
# 36         oracle.run1                      cores->oracle.run1
# 37               cores                      oracle.run1->cores
# 38         oracle.run1                      cores->oracle.run1
# 39         oracle.run1                      cores->oracle.run1
# 40               cores                      oracle.run1->cores
# 41               cores                      oracle.run1->cores

# %%
m = pd.melt(all_trials, 
        id_vars=["Transfer", "x_transform"], 
        value_vars=[
            "source_val_label_accuracy",
            "target_val_label_accuracy",
        ])
m
# Out:
#                      Transfer     x_transform                   variable  \
# 0   cores->oracle.run1.framed      Unit Power  source_val_label_accuracy
# 1   oracle.run1.framed->cores      Unit Power  source_val_label_accuracy
# 2   cores->oracle.run1.framed            None  source_val_label_accuracy
# 3   cores->oracle.run1.framed  Unit Magnitude  source_val_label_accuracy
# 4   oracle.run1.framed->cores  Unit Magnitude  source_val_label_accuracy
# ..                        ...             ...                        ...
# 79         oracle.run1->cores      Unit Power  target_val_label_accuracy
# 80         cores->oracle.run1            None  target_val_label_accuracy
# 81         cores->oracle.run1  Unit Magnitude  target_val_label_accuracy
# 82         oracle.run1->cores  Unit Magnitude  target_val_label_accuracy
# 83         oracle.run1->cores            None  target_val_label_accuracy
#
#        value
# 0   0.989375
# 1   0.869954
# 2   0.996250
# 3   0.987812
# 4   0.801465
# ..       ...
# 79  0.971250
# 80  0.388379
# 81  0.119036
# 82  0.966562
# 83  0.761563
#
# [84 rows x 4 columns]

# %%
matplotlib.rcParams.update({'font.size': 22})
plt.style.use('seaborn-whitegrid')

fg = sb.catplot(x='x_transform', col="Transfer", y='value', hue='variable', 
                        data=m, kind='bar', height=5, aspect=3, col_wrap=2, edgecolor = "black")
fg.set_xlabels('')
plt.figure(figsize=(15,50))

# iterate through axes
for ax in fg.axes.ravel():
    
    ax.tick_params(labelbottom=True)
    
    # add annotations
    for c in ax.containers:
        labels = [f'{(v.get_height()):.2f}' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge')
    ax.margins(y=0.2)
